# %% [markdown]
# ### Exerise 3
# for the given dataset, perform association rule mining with apriori through mlxtend and apyori libs respectively.

# %% [markdown]
# Note: This is a group excise.
# Recommendation for job breakdown of this group project:
# Some of the group members perform the apriori algorithm, while the rest perform the fp-growth algorithm. Each memeber submit the part of algorithm they have done and the rest of the group reviews and discusses the results.

# %%
dataset = [
    ["Bread", "Milk"],
    ["Bread", "Diaper", "Beer", "Eggs"],
    ["Milk", "Diaper", "Beer", "Cola"],
    ["Bread", "Milk", "Diaper", "Beer"],
    ["Bread", "Milk", "Diaper", "Cola"],
    ["Diaper", "Beer"],
    ["Bread", "Milk", "Beer"],
    ["Milk", "Diaper", "Beer", "Eggs"],
    ["Bread", "Milk", "Diaper", "Beer", "Eggs"],
    ["Bread", "Milk", "Diaper", "Cola", "Eggs"],
    ["Bread", "Milk", "Cheese"],
    ["Milk", "Yogurt", "Butter"],
    ["Bread", "Pasta", "Rice"],
    ["Milk", "Juice", "Chips"],
    ["Diaper", "Beer", "Soda"],
    ["Bread", "Milk", "Chocolate"],
    ["Milk", "Diaper", "Beer", "Cola"],
    ["Bread", "Milk", "Diaper", "Beer"],
    ["Bread", "Milk", "Diaper", "Cola"],
    ["Diaper", "Beer"],
    ["Bread", "Milk", "Beer"],
    ["Milk", "Diaper", "Beer", "Eggs"],
    ["Bread", "Milk", "Diaper", "Beer", "Eggs"],
    ["Bread", "Milk", "Diaper", "Cola", "Eggs"],
    ["Bread", "Milk", "Cheese"],
    ["Milk", "Yogurt", "Butter"],
    ["Bread", "Pasta", "Rice"],
    ["Milk", "Juice", "Chips"],
    ["Diaper", "Beer", "Soda"],
    ["Bread", "Milk", "Chocolate"],
    ["Milk", "Diaper", "Beer", "Cola"],
    ["Bread", "Milk", "Diaper", "Beer"],
    ["Bread", "Milk", "Diaper", "Cola"],
    ["Diaper", "Beer"],
    ["Bread", "Milk", "Beer"],
    ["Milk", "Diaper", "Beer", "Eggs"],
    ["Bread", "Milk", "Diaper", "Beer", "Eggs"],
    ["Bread", "Milk", "Diaper", "Cola", "Eggs"],
    ["Bread", "Milk", "Cheese"],
    ["Milk", "Yogurt", "Butter"],
    ["Bread", "Pasta", "Rice"],
    ["Milk", "Juice", "Chips"],
    ["Diaper", "Beer", "Soda"],
    ["Bread", "Milk", "Chocolate"],
    ["Milk", "Diaper", "Beer", "Cola"],
    ["Bread", "Milk", "Diaper", "Beer"],
    ["Bread", "Milk", "Diaper", "Cola"],
    ["Diaper", "Beer"],
    ["Bread", "Milk", "Beer"],
    ["Milk", "Diaper", "Beer", "Eggs"],
    ["Bread", "Milk", "Diaper", "Beer", "Eggs"],
    ["Bread", "Milk", "Diaper", "Cola", "Eggs"],
    ["Bread", "Milk", "Cheese"],
    ["Milk", "Yogurt", "Butter"],
    ["Bread", "Pasta", "Rice"],
    ["Milk", "Juice", "Chips"],
    ["Diaper", "Beer", "Soda"],
    ["Bread", "Milk", "Chocolate"],
    ["Milk", "Diaper", "Beer", "Cola"],
    ["Bread", "Milk", "Diaper", "Beer"],
    ["Bread", "Milk", "Diaper", "Cola"],
    ["Diaper", "Beer"],
    ["Bread", "Milk", "Beer"],
    ["Milk", "Diaper", "Beer", "Eggs"],
    ["Bread", "Milk", "Diaper", "Beer", "Eggs"],
    ["Bread", "Milk", "Diaper", "Cola", "Eggs"],
    ["Bread", "Milk", "Cheese"],
    ["Milk", "Yogurt", "Butter"],
    ["Bread", "Pasta", "Rice"],
    ["Milk", "Juice", "Chips"],
    ["Diaper", "Beer", "Soda"],
    ["Bread", "Milk", "Chocolate"],
    ["Milk", "Diaper", "Beer", "Cola"],
    ["Bread", "Milk", "Diaper", "Beer"],
    ["Bread", "Milk", "Diaper", "Cola"],
    ["Diaper", "Beer"],
    ["Bread", "Milk", "Beer"],
    ["Milk", "Diaper", "Beer", "Eggs"],
    ["Bread", "Milk", "Diaper", "Beer", "Eggs"],
    ["Bread", "Milk", "Diaper", "Cola", "Eggs"],
    ["Bread", "Milk", "Cheese"],
    ["Milk", "Yogurt", "Butter"],
    ["Bread", "Pasta", "Rice"],
    ["Milk", "Juice", "Chips"],
    ["Diaper", "Beer", "Soda"],
    ["Bread", "Milk", "Chocolate"],
    ["Milk", "Diaper", "Beer", "Cola"],
    ["Bread", "Milk", "Diaper", "Beer"],
    ["Bread", "Milk", "Diaper", "Cola"],
    ["Diaper", "Beer"],
    ["Bread", "Milk", "Beer"],
    ["Milk", "Diaper", "Beer", "Eggs"],
    ["Bread", "Milk", "Diaper", "Beer", "Eggs"],
    ["Bread", "Milk", "Diaper", "Cola", "Eggs"]
]
